# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import IFrame

# %%
plt.rc('font',size=14)
plt.rc('figure',figsize=(8,6))
plt.rc('text', usetex=True)

# %%
data = pd.read_csv('more_useful_data_isif_is_3.txt',sep=' ')

data=data.drop(columns=['Unnamed: 1','Unnamed: 2','|','band'])

data['system']=[(int(s.replace('ZrO2-',''))+1000)/1000 for s in data['system']]

# %% [markdown]
# # Vanda de Velencia

# %%
m_h_zg = data[(data['from']=='(Z)') & (data['to']=='(gamma)') &(data['no']==23)]

m_h_za = data[(data['from']=='(Z)') & (data['to']=='(A)')&(data['no']==23)]

# %%
m_h_za
# Out:
#     system  mass  value  no  spin from   to
# 2    1.000  m_h: -1.015  23  (up)  (Z)  (A)
# 12   1.005  m_h: -1.018  23  (up)  (Z)  (A)
# 22   1.010  m_h: -1.017  23  (up)  (Z)  (A)
# 32   1.015  m_h: -1.016  23  (up)  (Z)  (A)
# 42   1.020  m_h: -1.015  23  (up)  (Z)  (A)
# 52   1.025  m_h: -1.014  23  (up)  (Z)  (A)
# 62   1.030  m_h: -1.014  23  (up)  (Z)  (A)
# 72   1.035  m_h: -1.012  23  (up)  (Z)  (A)
# 82   1.040  m_h: -1.011  23  (up)  (Z)  (A)

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(m_h_zg['system'], m_h_zg['value'], label=r'$ Z \rightarrow\Gamma $')
ax[1].plot(m_h_za['system'], m_h_za['value'], label=r'$ X \rightarrow\Gamma $')
ax[0].set_title('valence band')
ax[1].set_xlabel(r'$a(\AA)$', fontsize=18)
ax[0].set_ylabel( r'$m^* (\hbar / m_e)$', fontsize=18)
ax[0].legend()
ax[1].legend()

# %% [markdown]
# # Banda de Conduccion

# %%
m_e_gz_wrong = data[(data['from']=='(gamma)') & (data['to']=='(Z)') & (data['spin']=='(up)')]
m_e_gx_wrong = data[(data['from']=='(gamma)') & (data['to']=='(X)') & (data['spin']=='(up)')]

# %%
m_e_gz_wrong
# Out:
#     system  mass  value  no  spin     from   to
# 7    1.000  m_e:  2.301  25  (up)  (gamma)  (Z)
# 17   1.005  m_e:  2.281  25  (up)  (gamma)  (Z)
# 27   1.010  m_e:  2.279  25  (up)  (gamma)  (Z)
# 37   1.015  m_e:  2.292  25  (up)  (gamma)  (Z)
# 47   1.020  m_e:  2.300  25  (up)  (gamma)  (Z)
# 57   1.025  m_e:  2.297  25  (up)  (gamma)  (Z)
# 67   1.030  m_e:  2.293  25  (up)  (gamma)  (Z)
# 77   1.035  m_e:  2.315  25  (up)  (gamma)  (Z)
# 87   1.040  m_e:  2.312  25  (up)  (gamma)  (Z)

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].plot(m_e_gz['system'], m_e_gz['value'], label=r'$ \Gamma \rightarrow Z$')
ax[1].plot(m_e_gx['system'], m_e_gx['value'], label=r'$ \Gamma \rightarrow X$')
ax[1].set_title('valence band')
ax[1].set_xlabel(r'$a(\AA)$', fontsize=18)
ax[0].set_ylabel( r'$m^* (\hbar / m_e)$', fontsize=18)
ax[0].legend()
ax[1].legend()

# %% [markdown]
# lo que me pregunto es qué tan mal estaba el voumen. efectivamente los cambios de parametro de red son demasiado pequeños y estan pasando cosas raras.
# Notar que hay cambios de pendiente para a = 1.005

# %%
datavol = pd.read_csv('datavol.dat', sep=' ')

# %%
datavol_isif_3 = pd.read_csv('datavol-isif-is-3.dat', sep=' ')

# %%
datavol
# Out:
#             dir    Vol      Evsk1      Evsk2      Evsk3      Evsk4      Evsk5
# 0   ZrO2-new-00  60.12 -55.667443 -55.667753 -55.667880 -55.667996 -55.667977
# 1   ZrO2-new-01  62.04 -56.094109 -56.094426 -56.094536 -56.094685 -56.094681
# 2   ZrO2-new-02  64.00 -56.406923 -56.407263 -56.407358 -56.407542 -56.407542
# 3   ZrO2-new-03  66.00 -56.623984 -56.624284 -56.624425 -56.624598 -56.624596
# 4   ZrO2-new-04  68.04 -56.751131 -56.751468 -56.751562 -56.751755 -56.751756
# 5   ZrO2-new-05  70.12 -56.798684 -56.799052 -56.799160 -56.799361 -56.799352
# 6   ZrO2-new-06  72.25 -56.776327 -56.776549 -56.776701 -56.776968 -56.777007
# 7   ZrO2-new-07  74.41 -56.690390 -56.690756 -56.690936 -56.691185 -56.691240
# 8   ZrO2-new-08  76.62 -56.553318 -56.551013 -56.551358 -56.551635 -56.551755
# 9   ZrO2-new-09  78.88 -56.364329 -56.361616 -56.361981 -56.362361 -56.362521
# 10  ZrO2-new-10  81.17 -56.131944 -56.132281 -56.130020 -56.129909 -56.129956
# 11  ZrO2-new-11  83.51 -55.861763 -55.858889 -55.859274 -55.859740 -55.860007
# 12  ZrO2-new-12  85.90 -55.558600 -55.555534 -55.555878 -55.556296 -55.556496

# %%
datavol_isif_3
# Out:
#        dir    Vol      Evsk1      Evsk2      Evsk3      Evsk4
# 0  ZrO2-00  70.36 -56.799951 -56.800296 -56.800426 -56.800362
# 1  ZrO2-05  70.29 -56.799831 -56.800184 -56.800308 -56.800263
# 2  ZrO2-10  70.30 -56.800163 -56.800509 -56.800648 -56.800565
# 3  ZrO2-15  70.34 -56.800452 -56.800794 -56.800938 -56.800874
# 4  ZrO2-20  70.39 -56.800705 -56.801042 -56.801191 -56.801153
# 5  ZrO2-25  70.42 -56.800891 -56.801220 -56.801383 -56.801314
# 6  ZrO2-30  70.49 -56.800999 -56.801354 -56.801510 -56.801440
# 7  ZrO2-35  70.65 -56.800791 -56.801153 -56.801305 -56.801264
# 8  ZrO2-40  70.70 -56.800726 -56.801072 -56.801231 -56.801192

# %% [markdown]
# dos conclusiones de ese grafico:
# 1. los volumenes son cualquiera,
# 2. no estaba convergido en puntos k.

# %% [markdown]
# # Rehaciendo calculos mejor

# %%
fig, ax = plt.subplots(1,2, figsize=(15,8))
ax[0].plot(datavol['Vol'], datavol['Evsk1'],'-o', label='9x9x7', ms=10)
ax[0].plot(datavol['Vol'], datavol['Evsk2'],'-o', label='11x11x9',ms=8)
ax[0].plot(datavol['Vol'], datavol['Evsk3'],'-o', label='13x13x11', ms = 6)
ax[0].plot(datavol['Vol'], datavol['Evsk4'],'-o', label='15x15x9', ms=4)
ax[0].plot(datavol['Vol'], datavol['Evsk5'],'-o', label='17x17x9', ms=2)
ax[0].legend()
for i in datavol.index:
    ax[1].plot(datavol.loc[i][2:]-datavol.loc[i][-1],label=datavol.loc[i][0])
ax[1].legend()
ax[0].set_xlabel(r'cell vol ($\AA$)')
ax[0].set_ylabel('E (eV)')
# Out:
# Text(0, 0.5, 'E (eV)')

# %%
datavol[datavol['dir']=='ZrO2-new-00'].as_matrix()[0,1:]
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([60.12, -55.667443000000006, -55.667753000000005,
#        -55.667880000000004, -55.667995999999995, -55.667977], dtype=object)

# %% [markdown]
# el volumen de minima energía es:

# %%
# vopt = datavol['Vol'][datavol['evsk4'].dimin()]
vopt=datavol['Vol'][datavol['Evsk4'].idxmin()]

# %%
vopt
# Out:
# 70.12

# %% [markdown]
# # Estructura de bandas con calculo bueno

# %%
databands = pd.read_csv('more_useful_data.txt',sep='#')

# %%
databands
# Out:
#        Vol mass   value  bandno    spin                from     fname  \
# 0    60.12  m_h  -0.588      23    (up)  [0.50, 0.50, 0.50]       (A)
# 1    60.12  m_h  -0.605      23    (up)  [0.50, 0.50, 0.50]       (A)
# 2    60.12  m_h  -0.588      24    (up)  [0.50, 0.50, 0.50]       (A)
# 3    60.12  m_h  -0.605      24    (up)  [0.50, 0.50, 0.50]       (A)
# 4    60.12  m_e   0.557      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 5    60.12  m_e   1.946      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 6    60.12  m_e   0.557      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 7    60.12  m_e  16.797      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 8    62.04  m_h  -0.628      23    (up)  [0.50, 0.50, 0.50]       (A)
# 9    62.04  m_h  -0.646      23    (up)  [0.50, 0.50, 0.50]       (A)
# 10   62.04  m_h  -0.628      24    (up)  [0.50, 0.50, 0.50]       (A)
# 11   62.04  m_h  -0.646      24    (up)  [0.50, 0.50, 0.50]       (A)
# 12   62.04  m_e   0.578      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 13   62.04  m_e   2.013      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 14   62.04  m_e   0.578      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 15   62.04  m_e  16.448      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 16   64.00  m_h  -0.715      23    (up)  [0.50, 0.50, 0.50]       (A)
# 17   64.00  m_h  -0.733      23    (up)  [0.50, 0.50, 0.50]       (A)
# 18   64.00  m_h  -0.715      24    (up)  [0.50, 0.50, 0.50]       (A)
# 19   64.00  m_h  -0.733      24    (up)  [0.50, 0.50, 0.50]       (A)
# 20   64.00  m_e   0.592      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 21   64.00  m_e   2.057      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 22   64.00  m_e   0.592      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 23   64.00  m_e  17.454      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 24   66.00  m_h  -0.786      23    (up)  [0.50, 0.50, 0.50]       (A)
# 25   66.00  m_h  -0.804      23    (up)  [0.50, 0.50, 0.50]       (A)
# 26   66.00  m_h  -0.786      24    (up)  [0.50, 0.50, 0.50]       (A)
# 27   66.00  m_h  -0.804      24    (up)  [0.50, 0.50, 0.50]       (A)
# 28   66.00  m_e   0.609      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 29   66.00  m_e   2.129      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# ..     ...  ...     ...     ...     ...                 ...       ...
# 76   78.88  m_h  -3.486      24  (down)  [0.35, 0.00, 0.00]       NaN
# 77   78.88  m_h  -2.809      24  (down)  [0.35, 0.00, 0.00]       NaN
# 78   78.88  m_e   0.625      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 79   78.88  m_e   2.595      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 80   78.88  m_e   0.625      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 81   78.88  m_e  22.775      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 82   81.17  m_h  -2.661      24    (up)  [0.35, 0.00, 0.00]       NaN
# 83   81.17  m_h  -2.511      24    (up)  [0.35, 0.00, 0.00]       NaN
# 84   81.17  m_h  -2.661      24  (down)  [0.35, 0.00, 0.00]       NaN
# 85   81.17  m_h  -2.511      24  (down)  [0.35, 0.00, 0.00]       NaN
# 86   81.17  m_e   0.619      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 87   81.17  m_e   2.700      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 88   81.17  m_e   0.619      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 89   81.17  m_e  22.343      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 90   83.51  m_h  -2.217      24    (up)  [0.35, 0.00, 0.00]       NaN
# 91   83.51  m_h  -2.049      24    (up)  [0.35, 0.00, 0.00]       NaN
# 92   83.51  m_h  -2.217      24  (down)  [0.35, 0.00, 0.00]       NaN
# 93   83.51  m_h  -2.049      24  (down)  [0.35, 0.00, 0.00]       NaN
# 94   83.51  m_e   0.613      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 95   83.51  m_e   2.793      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 96   83.51  m_e   0.613      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 97   83.51  m_e  25.055      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 98   85.90  m_h  -1.989      24    (up)  [0.35, 0.00, 0.00]       NaN
# 99   85.90  m_h  -1.589      24    (up)  [0.35, 0.00, 0.00]       NaN
# 100  85.90  m_h  -1.989      24  (down)  [0.35, 0.00, 0.00]       NaN
# 101  85.90  m_h  -1.589      24  (down)  [0.35, 0.00, 0.00]       NaN
# 102  85.90  m_e   0.605      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 103  85.90  m_e   2.878      25    (up)  [0.00, 0.00, 0.00]   (gamma)
# 104  85.90  m_e   0.605      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 105  85.90  m_e  24.589      25  (down)  [0.00, 0.00, 0.00]   (gamma)
#
#                      to   toname
# 0    [0.00, 0.50, 0.50]      (R)
# 1    [0.00, 0.00, 0.50]      (Z)
# 2    [0.00, 0.50, 0.50]      (R)
# 3    [0.00, 0.00, 0.50]      (Z)
# 4    [0.50, 0.00, 0.00]      (X)
# 5    [0.00, 0.00, 0.50]      (Z)
# 6    [0.50, 0.00, 0.00]      (X)
# 7    [0.00, 0.00, 0.50]      (Z)
# 8    [0.00, 0.50, 0.50]      (R)
# 9    [0.00, 0.00, 0.50]      (Z)
# 10   [0.00, 0.50, 0.50]      (R)
# 11   [0.00, 0.00, 0.50]      (Z)
# 12   [0.50, 0.00, 0.00]      (X)
# 13   [0.00, 0.00, 0.50]      (Z)
# 14   [0.50, 0.00, 0.00]      (X)
# 15   [0.00, 0.00, 0.50]      (Z)
# 16   [0.00, 0.50, 0.50]      (R)
# 17   [0.00, 0.00, 0.50]      (Z)
# 18   [0.00, 0.50, 0.50]      (R)
# 19   [0.00, 0.00, 0.50]      (Z)
# 20   [0.50, 0.00, 0.00]      (X)
# 21   [0.00, 0.00, 0.50]      (Z)
# 22   [0.50, 0.00, 0.00]      (X)
# 23   [0.00, 0.00, 0.50]      (Z)
# 24   [0.00, 0.50, 0.50]      (R)
# 25   [0.00, 0.00, 0.50]      (Z)
# 26   [0.00, 0.50, 0.50]      (R)
# 27   [0.00, 0.00, 0.50]      (Z)
# 28   [0.50, 0.00, 0.00]      (X)
# 29   [0.00, 0.00, 0.50]      (Z)
# ..                  ...      ...
# 76   [0.00, 0.00, 0.00]  (gamma)
# 77   [0.50, 0.00, 0.00]      (X)
# 78   [0.50, 0.00, 0.00]      (X)
# 79   [0.00, 0.00, 0.50]      (Z)
# 80   [0.50, 0.00, 0.00]      (X)
# 81   [0.00, 0.00, 0.50]      (Z)
# 82   [0.00, 0.00, 0.00]  (gamma)
# 83   [0.50, 0.00, 0.00]      (X)
# 84   [0.00, 0.00, 0.00]  (gamma)
# 85   [0.50, 0.00, 0.00]      (X)
# 86   [0.50, 0.00, 0.00]      (X)
# 87   [0.00, 0.00, 0.50]      (Z)
# 88   [0.50, 0.00, 0.00]      (X)
# 89   [0.00, 0.00, 0.50]      (Z)
# 90   [0.00, 0.00, 0.00]  (gamma)
# 91   [0.50, 0.00, 0.00]      (X)
# 92   [0.00, 0.00, 0.00]  (gamma)
# 93   [0.50, 0.00, 0.00]      (X)
# 94   [0.50, 0.00, 0.00]      (X)
# 95   [0.00, 0.00, 0.50]      (Z)
# 96   [0.50, 0.00, 0.00]      (X)
# 97   [0.00, 0.00, 0.50]      (Z)
# 98   [0.00, 0.00, 0.00]  (gamma)
# 99   [0.50, 0.00, 0.00]      (X)
# 100  [0.00, 0.00, 0.00]  (gamma)
# 101  [0.50, 0.00, 0.00]      (X)
# 102  [0.50, 0.00, 0.00]      (X)
# 103  [0.00, 0.00, 0.50]      (Z)
# 104  [0.50, 0.00, 0.00]      (X)
# 105  [0.00, 0.00, 0.50]      (Z)
#
# [106 rows x 9 columns]

# %% [markdown]
# ## masa del electron

# %%
m_e = databands[(databands['mass']=='m_e')]
m_e_gx_up = m_e[(m_e['toname']=='(X)') & (m_e['spin']=='(up)')]
m_e_gx_dn = m_e[(m_e['toname']=='(X)') & (m_e['spin']=='(down)')]
m_e_gz_up = m_e[(m_e['toname']=='(Z)') & (m_e['spin']=='(up)')]
m_e_gz_dn = m_e[(m_e['toname']=='(Z)') & (m_e['spin']=='(down)')]

# %% [markdown]
# ### electron en el camino $\Gamma \rightarrow Z$, spin down

# %%
m_e_gz_dn
# Out:
#        Vol mass   value  bandno    spin                from     fname  \
# 7    60.12  m_e  16.797      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 15   62.04  m_e  16.448      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 23   64.00  m_e  17.454      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 31   66.00  m_e  18.654      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 39   68.04  m_e  18.279      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 49   70.12  m_e  19.707      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 57   72.25  m_e  19.318      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 65   74.41  m_e  21.046      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 73   76.62  m_e  20.639      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 81   78.88  m_e  22.775      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 89   81.17  m_e  22.343      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 97   83.51  m_e  25.055      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 105  85.90  m_e  24.589      25  (down)  [0.00, 0.00, 0.00]   (gamma)
#
#                      to toname
# 7    [0.00, 0.00, 0.50]    (Z)
# 15   [0.00, 0.00, 0.50]    (Z)
# 23   [0.00, 0.00, 0.50]    (Z)
# 31   [0.00, 0.00, 0.50]    (Z)
# 39   [0.00, 0.00, 0.50]    (Z)
# 49   [0.00, 0.00, 0.50]    (Z)
# 57   [0.00, 0.00, 0.50]    (Z)
# 65   [0.00, 0.00, 0.50]    (Z)
# 73   [0.00, 0.00, 0.50]    (Z)
# 81   [0.00, 0.00, 0.50]    (Z)
# 89   [0.00, 0.00, 0.50]    (Z)
# 97   [0.00, 0.00, 0.50]    (Z)
# 105  [0.00, 0.00, 0.50]    (Z)

# %% [markdown]
# ### spin up

# %%
m_e_gz_up
# Out:
#        Vol mass  value  bandno  spin                from     fname  \
# 5    60.12  m_e  1.946      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 13   62.04  m_e  2.013      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 21   64.00  m_e  2.057      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 29   66.00  m_e  2.129      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 37   68.04  m_e  2.200      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 47   70.12  m_e  2.265      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 55   72.25  m_e  2.356      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 63   74.41  m_e  2.441      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 71   76.62  m_e  2.490      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 79   78.88  m_e  2.595      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 87   81.17  m_e  2.700      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 95   83.51  m_e  2.793      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 103  85.90  m_e  2.878      25  (up)  [0.00, 0.00, 0.00]   (gamma)
#
#                      to toname
# 5    [0.00, 0.00, 0.50]    (Z)
# 13   [0.00, 0.00, 0.50]    (Z)
# 21   [0.00, 0.00, 0.50]    (Z)
# 29   [0.00, 0.00, 0.50]    (Z)
# 37   [0.00, 0.00, 0.50]    (Z)
# 47   [0.00, 0.00, 0.50]    (Z)
# 55   [0.00, 0.00, 0.50]    (Z)
# 63   [0.00, 0.00, 0.50]    (Z)
# 71   [0.00, 0.00, 0.50]    (Z)
# 79   [0.00, 0.00, 0.50]    (Z)
# 87   [0.00, 0.00, 0.50]    (Z)
# 95   [0.00, 0.00, 0.50]    (Z)
# 103  [0.00, 0.00, 0.50]    (Z)

# %% [markdown]
# notar que en este camino la masa para espin down es 10 veces mayor que con spin down.

# %% [markdown]
# ## electron camino $\Gamma \rightarrow X$

# %%
m_e_gx_up
# Out:
#        Vol mass  value  bandno  spin                from     fname  \
# 4    60.12  m_e  0.557      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 12   62.04  m_e  0.578      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 20   64.00  m_e  0.592      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 28   66.00  m_e  0.609      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 36   68.04  m_e  0.620      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 46   70.12  m_e  0.629      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 54   72.25  m_e  0.630      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 62   74.41  m_e  0.635      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 70   76.62  m_e  0.623      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 78   78.88  m_e  0.625      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 86   81.17  m_e  0.619      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 94   83.51  m_e  0.613      25  (up)  [0.00, 0.00, 0.00]   (gamma)
# 102  85.90  m_e  0.605      25  (up)  [0.00, 0.00, 0.00]   (gamma)
#
#                      to toname
# 4    [0.50, 0.00, 0.00]    (X)
# 12   [0.50, 0.00, 0.00]    (X)
# 20   [0.50, 0.00, 0.00]    (X)
# 28   [0.50, 0.00, 0.00]    (X)
# 36   [0.50, 0.00, 0.00]    (X)
# 46   [0.50, 0.00, 0.00]    (X)
# 54   [0.50, 0.00, 0.00]    (X)
# 62   [0.50, 0.00, 0.00]    (X)
# 70   [0.50, 0.00, 0.00]    (X)
# 78   [0.50, 0.00, 0.00]    (X)
# 86   [0.50, 0.00, 0.00]    (X)
# 94   [0.50, 0.00, 0.00]    (X)
# 102  [0.50, 0.00, 0.00]    (X)

# %% [markdown]
# ### spin down

# %%
m_e_gx_dn
# Out:
#        Vol mass  value  bandno    spin                from     fname  \
# 6    60.12  m_e  0.557      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 14   62.04  m_e  0.578      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 22   64.00  m_e  0.592      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 30   66.00  m_e  0.609      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 38   68.04  m_e  0.620      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 48   70.12  m_e  0.629      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 56   72.25  m_e  0.630      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 64   74.41  m_e  0.635      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 72   76.62  m_e  0.623      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 80   78.88  m_e  0.625      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 88   81.17  m_e  0.619      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 96   83.51  m_e  0.613      25  (down)  [0.00, 0.00, 0.00]   (gamma)
# 104  85.90  m_e  0.605      25  (down)  [0.00, 0.00, 0.00]   (gamma)
#
#                      to toname
# 6    [0.50, 0.00, 0.00]    (X)
# 14   [0.50, 0.00, 0.00]    (X)
# 22   [0.50, 0.00, 0.00]    (X)
# 30   [0.50, 0.00, 0.00]    (X)
# 38   [0.50, 0.00, 0.00]    (X)
# 48   [0.50, 0.00, 0.00]    (X)
# 56   [0.50, 0.00, 0.00]    (X)
# 64   [0.50, 0.00, 0.00]    (X)
# 72   [0.50, 0.00, 0.00]    (X)
# 80   [0.50, 0.00, 0.00]    (X)
# 88   [0.50, 0.00, 0.00]    (X)
# 96   [0.50, 0.00, 0.00]    (X)
# 104  [0.50, 0.00, 0.00]    (X)

# %% [markdown]
# En este camino, ambas masas (up y down) son iguales.

# %% [markdown]
# ### gráficos para electron

# %%
fig, ax = plt.subplots(2,1, sharex=True)
ax[0].set_title('conduction band')
ax[0].plot(m_e_gx_up['Vol'], m_e_gx_up['value'],'-o', label=r'up, $ \Gamma \rightarrow X$')
ax[0].plot(m_e_gx_dn['Vol'], m_e_gx_dn['value'],'-o', label=r'down, $ \Gamma \rightarrow X$')
#ax[0].plot(m_e_gz['Vol'], m_e_gz['value'],'-o', label=r'$ \Gamma \rightarrow Z$')
ax[1].plot(m_e_gz_up['Vol'], m_e_gz_up['value'],'-o', label=r'up, $ \Gamma \rightarrow Z$')
ax[1].plot(m_e_gz_dn['Vol'], m_e_gz_dn['value']/10,'-o', label=r'down, $\times \frac{1}{10}, \Gamma \rightarrow Z$')
ax[1].set_xlabel(r'$a(\AA)$', fontsize=18)
ax[0].axvline(vopt,c='k')
ax[1].axvline(vopt,c='k')
ax[0].set_ylabel( r'$m^* (\hbar / m_e)$', fontsize=18)
ax[0].legend()
ax[1].legend()

# %% [markdown]
# # masas del hueco

# %% [markdown]
# la masa del hueco tiene un comportamiento mas raro. para empezar, esta desdoblada en dos bandas segun la direccion.

# %%
m_h = databands[(databands['mass']=='m_h')]
# m_h = databands[(databands['fname']=='(gamma)') & (databands['toname']=='(X)') & (databands['spin']=='(up)')]

# %%
m_h_za = databands[(databands['mass']=='m_h') & (databands['toname']=='(A)')]
m_h_zr = databands[(databands['mass']=='m_h') & (databands['toname']=='(R)')]
m_h_tz = databands[(databands['mass']=='m_h') & (databands['toname']=='(Z)')]
m_h_fz = databands[(databands['mass']=='m_h') & (databands['fname']==' (Z)')]

# %% [markdown]
# ## Hueco en el camino $Z \rightarrow A$

# %%
m_h_za
# Out:
#       Vol mass  value  bandno  spin                from fname  \
# 42  70.12  m_h -1.023      23  (up)  [0.00, 0.00, 0.50]   (Z)
# 45  70.12  m_h -1.023      24  (up)  [0.00, 0.00, 0.50]   (Z)
#
#                     to toname
# 42  [0.50, 0.50, 0.50]    (A)
# 45  [0.50, 0.50, 0.50]    (A)

# %% [markdown]
# ### En el camino $A \rightarrow R$

# %%
m_h_zr
# Out:
#       Vol mass  value  bandno  spin                from fname  \
# 0   60.12  m_h -0.588      23  (up)  [0.50, 0.50, 0.50]   (A)
# 2   60.12  m_h -0.588      24  (up)  [0.50, 0.50, 0.50]   (A)
# 8   62.04  m_h -0.628      23  (up)  [0.50, 0.50, 0.50]   (A)
# 10  62.04  m_h -0.628      24  (up)  [0.50, 0.50, 0.50]   (A)
# 16  64.00  m_h -0.715      23  (up)  [0.50, 0.50, 0.50]   (A)
# 18  64.00  m_h -0.715      24  (up)  [0.50, 0.50, 0.50]   (A)
# 24  66.00  m_h -0.786      23  (up)  [0.50, 0.50, 0.50]   (A)
# 26  66.00  m_h -0.786      24  (up)  [0.50, 0.50, 0.50]   (A)
# 32  68.04  m_h -0.899      23  (up)  [0.50, 0.50, 0.50]   (A)
# 34  68.04  m_h -0.899      24  (up)  [0.50, 0.50, 0.50]   (A)
# 41  70.12  m_h -0.715      23  (up)  [0.00, 0.00, 0.50]   (Z)
# 44  70.12  m_h -1.301      24  (up)  [0.00, 0.00, 0.50]   (Z)
#
#                     to toname
# 0   [0.00, 0.50, 0.50]    (R)
# 2   [0.00, 0.50, 0.50]    (R)
# 8   [0.00, 0.50, 0.50]    (R)
# 10  [0.00, 0.50, 0.50]    (R)
# 16  [0.00, 0.50, 0.50]    (R)
# 18  [0.00, 0.50, 0.50]    (R)
# 24  [0.00, 0.50, 0.50]    (R)
# 26  [0.00, 0.50, 0.50]    (R)
# 32  [0.00, 0.50, 0.50]    (R)
# 34  [0.00, 0.50, 0.50]    (R)
# 41  [0.00, 0.50, 0.50]    (R)
# 44  [0.00, 0.50, 0.50]    (R)

# %%
m_h_tz
# Out:
#       Vol mass  value  bandno  spin                from fname  \
# 1   60.12  m_h -0.605      23  (up)  [0.50, 0.50, 0.50]   (A)
# 3   60.12  m_h -0.605      24  (up)  [0.50, 0.50, 0.50]   (A)
# 9   62.04  m_h -0.646      23  (up)  [0.50, 0.50, 0.50]   (A)
# 11  62.04  m_h -0.646      24  (up)  [0.50, 0.50, 0.50]   (A)
# 17  64.00  m_h -0.733      23  (up)  [0.50, 0.50, 0.50]   (A)
# 19  64.00  m_h -0.733      24  (up)  [0.50, 0.50, 0.50]   (A)
# 25  66.00  m_h -0.804      23  (up)  [0.50, 0.50, 0.50]   (A)
# 27  66.00  m_h -0.804      24  (up)  [0.50, 0.50, 0.50]   (A)
# 33  68.04  m_h -0.919      23  (up)  [0.50, 0.50, 0.50]   (A)
# 35  68.04  m_h -0.919      24  (up)  [0.50, 0.50, 0.50]   (A)
#
#                     to toname
# 1   [0.00, 0.00, 0.50]    (Z)
# 3   [0.00, 0.00, 0.50]    (Z)
# 9   [0.00, 0.00, 0.50]    (Z)
# 11  [0.00, 0.00, 0.50]    (Z)
# 17  [0.00, 0.00, 0.50]    (Z)
# 19  [0.00, 0.00, 0.50]    (Z)
# 25  [0.00, 0.00, 0.50]    (Z)
# 27  [0.00, 0.00, 0.50]    (Z)
# 33  [0.00, 0.00, 0.50]    (Z)
# 35  [0.00, 0.00, 0.50]    (Z)

# %%
m_h_fz
# Out:
#       Vol mass  value  bandno  spin                from fname  \
# 40  70.12  m_h -7.820      23  (up)  [0.00, 0.00, 0.50]   (Z)
# 41  70.12  m_h -0.715      23  (up)  [0.00, 0.00, 0.50]   (Z)
# 42  70.12  m_h -1.023      23  (up)  [0.00, 0.00, 0.50]   (Z)
# 43  70.12  m_h -7.820      24  (up)  [0.00, 0.00, 0.50]   (Z)
# 44  70.12  m_h -1.301      24  (up)  [0.00, 0.00, 0.50]   (Z)
# 45  70.12  m_h -1.023      24  (up)  [0.00, 0.00, 0.50]   (Z)
#
#                     to   toname
# 40  [0.00, 0.00, 0.00]  (gamma)
# 41  [0.00, 0.50, 0.50]      (R)
# 42  [0.50, 0.50, 0.50]      (A)
# 43  [0.00, 0.00, 0.00]  (gamma)
# 44  [0.00, 0.50, 0.50]      (R)
# 45  [0.50, 0.50, 0.50]      (A)

# %% [markdown]
# todos los valores que puse ahi estan $v < v_{eq}$, que pasa arriva ?

# %%
m_h_vbig = databands[(databands['Vol']>vopt) & (databands['mass']=='m_h')]

# %%
m_h_vbig
# Out:
#        Vol mass  value  bandno    spin                from fname  \
# 50   72.25  m_h -4.311      24    (up)  [0.31, 0.00, 0.00]   NaN
# 51   72.25  m_h -6.054      24    (up)  [0.31, 0.00, 0.00]   NaN
# 52   72.25  m_h -4.311      24  (down)  [0.31, 0.00, 0.00]   NaN
# 53   72.25  m_h -6.054      24  (down)  [0.31, 0.00, 0.00]   NaN
# 58   74.41  m_h -5.110      24    (up)  [0.33, 0.00, 0.00]   NaN
# 59   74.41  m_h -4.245      24    (up)  [0.33, 0.00, 0.00]   NaN
# 60   74.41  m_h -5.110      24  (down)  [0.33, 0.00, 0.00]   NaN
# 61   74.41  m_h -4.245      24  (down)  [0.33, 0.00, 0.00]   NaN
# 66   76.62  m_h -4.696      24    (up)  [0.35, 0.00, 0.00]   NaN
# 67   76.62  m_h -2.826      24    (up)  [0.35, 0.00, 0.00]   NaN
# 68   76.62  m_h -4.696      24  (down)  [0.35, 0.00, 0.00]   NaN
# 69   76.62  m_h -2.826      24  (down)  [0.35, 0.00, 0.00]   NaN
# 74   78.88  m_h -3.486      24    (up)  [0.35, 0.00, 0.00]   NaN
# 75   78.88  m_h -2.809      24    (up)  [0.35, 0.00, 0.00]   NaN
# 76   78.88  m_h -3.486      24  (down)  [0.35, 0.00, 0.00]   NaN
# 77   78.88  m_h -2.809      24  (down)  [0.35, 0.00, 0.00]   NaN
# 82   81.17  m_h -2.661      24    (up)  [0.35, 0.00, 0.00]   NaN
# 83   81.17  m_h -2.511      24    (up)  [0.35, 0.00, 0.00]   NaN
# 84   81.17  m_h -2.661      24  (down)  [0.35, 0.00, 0.00]   NaN
# 85   81.17  m_h -2.511      24  (down)  [0.35, 0.00, 0.00]   NaN
# 90   83.51  m_h -2.217      24    (up)  [0.35, 0.00, 0.00]   NaN
# 91   83.51  m_h -2.049      24    (up)  [0.35, 0.00, 0.00]   NaN
# 92   83.51  m_h -2.217      24  (down)  [0.35, 0.00, 0.00]   NaN
# 93   83.51  m_h -2.049      24  (down)  [0.35, 0.00, 0.00]   NaN
# 98   85.90  m_h -1.989      24    (up)  [0.35, 0.00, 0.00]   NaN
# 99   85.90  m_h -1.589      24    (up)  [0.35, 0.00, 0.00]   NaN
# 100  85.90  m_h -1.989      24  (down)  [0.35, 0.00, 0.00]   NaN
# 101  85.90  m_h -1.589      24  (down)  [0.35, 0.00, 0.00]   NaN
#
#                      to   toname
# 50   [0.00, 0.00, 0.00]  (gamma)
# 51   [0.50, 0.00, 0.00]      (X)
# 52   [0.00, 0.00, 0.00]  (gamma)
# 53   [0.50, 0.00, 0.00]      (X)
# 58   [0.00, 0.00, 0.00]  (gamma)
# 59   [0.50, 0.00, 0.00]      (X)
# 60   [0.00, 0.00, 0.00]  (gamma)
# 61   [0.50, 0.00, 0.00]      (X)
# 66   [0.00, 0.00, 0.00]  (gamma)
# 67   [0.50, 0.00, 0.00]      (X)
# 68   [0.00, 0.00, 0.00]  (gamma)
# 69   [0.50, 0.00, 0.00]      (X)
# 74   [0.00, 0.00, 0.00]  (gamma)
# 75   [0.50, 0.00, 0.00]      (X)
# 76   [0.00, 0.00, 0.00]  (gamma)
# 77   [0.50, 0.00, 0.00]      (X)
# 82   [0.00, 0.00, 0.00]  (gamma)
# 83   [0.50, 0.00, 0.00]      (X)
# 84   [0.00, 0.00, 0.00]  (gamma)
# 85   [0.50, 0.00, 0.00]      (X)
# 90   [0.00, 0.00, 0.00]  (gamma)
# 91   [0.50, 0.00, 0.00]      (X)
# 92   [0.00, 0.00, 0.00]  (gamma)
# 93   [0.50, 0.00, 0.00]      (X)
# 98   [0.00, 0.00, 0.00]  (gamma)
# 99   [0.50, 0.00, 0.00]      (X)
# 100  [0.00, 0.00, 0.00]  (gamma)
# 101  [0.50, 0.00, 0.00]      (X)

# %% [markdown]
# es curioso que para volumenes grandes, el máximo de la banda de valencia se corre de $Z$ a $[0.33, 0, 0 ]$ !

# %%
IFrame('ZrO2-new-05/BANDSdir/ZrO2-new-05_band.pdf',width=400, height=300)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="ZrO2-new-05/BANDSdir/ZrO2-new-05_band.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('ZrO2-new-06/BANDSdir/ZrO2-new-06_band.pdf',width=400, height=300)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="ZrO2-new-06/BANDSdir/ZrO2-new-06_band.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('ZrO2-new-07/BANDSdir/ZrO2-new-07_band.pdf',width=400, height=300)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="ZrO2-new-07/BANDSdir/ZrO2-new-07_band.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('ZrO2-new-10/BANDSdir/ZrO2-new-10_band.pdf',width=400, height=300)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="ZrO2-new-10/BANDSdir/ZrO2-new-10_band.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
